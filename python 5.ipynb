# %%
import pandas as pandas

# %%
import xlrd

# %%
import numpy as numpy

# %%
excel = pandas.read_excel("https://www.czso.cz/documents/10180/32853391/300002164403.xlsx/1fed9fb2-4dbf-4b0f-bfbe-4c2d3202a18f?version=1.1", header =None ,  skiprows = 6)
excel.fillna('')
excel = excel.drop(excel.index[[1,4,7,41,42,43,36]])
excel = excel.drop(excel.columns[17,],axis=1)
excel
# Out:
#                  0                                                 1     2   \
# 0              Země  Studují či se jinak připravují na výkon povolání   NaN
# 2               NaN                               15 - 24 let / years   NaN
# 3               NaN                                              ženy   NaN
# 5             EU 28                                               NaN  87.5
# 6       Eurozóna 19                                               NaN  89.4
# 8            Belgie                                               NaN  90.5
# 9         Bulharsko                                               NaN  79.8
# 10  Česká republika                                               NaN  90.0
# 11           Dánsko                                               NaN  84.9
# 12         Estonsko                                               NaN  83.9
# 13           Finsko                                               NaN  76.4
# ...

# %%
ex=excel.fillna('')
col1 = ex.iloc[0]
col2 = ex.iloc[1]
col3 = ex.iloc[2]
columns = [col1, col2,col3]

columns = list(zip(*columns))

ex.columns = columns
ex.columns = pandas.MultiIndex.from_tuples(ex.columns, names=["",'',""])
ex = ex.drop(ex.index[[0,1,2]])

ex
# Out:
#                Země Studují či se jinak připravují na výkon povolání        \
#                                                  15 - 24 let / years
#                                                                 ženy
# 5             EU 28                                                   87.5
# 6       Eurozóna 19                                                   89.4
# 8            Belgie                                                   90.5
# 9         Bulharsko                                                   79.8
# 10  Česká republika                                                     90
# 11           Dánsko                                                   84.9
# 12         Estonsko                                                   83.9
# 13           Finsko                                                   76.4
# 14          Francie                                                   91.5
# 15       Chorvatsko                                                   93.2
# ...
